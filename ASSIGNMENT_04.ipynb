# %% [markdown]
# <a href="https://colab.research.google.com/github/WaleedBahtti/Assignments/blob/main/ASSIGNMENT_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
SUBJECT=['Islamyat', 'Programming Fundamental', 'I.C.T', 'Calculus', 'Basic Electronics']
MARKS=[66,65,67,60,70]
plt.pie(MARKS, labels=SUBJECT,autopct='%0.2f%%',radius=2,shadow=True)
plt.show()
